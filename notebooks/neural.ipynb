# %%
# %%capture
# !pip3 install sklearn
# !pip3 install matplotlib
# !pip3 install xgboost
# !pip3 install pandas

# %%
sys.path.append('../src/')
from PredictPRInKP import *

# %%
import PredictPRInKP as PredictPRInKP
from PredictPRInKP import * 


datasets_full = ['dataset_1_', 'dataset_2_','dataset_3_','dataset_7_']
datasets_gwas = []

# %%
feature_selection = {"method": "Select From Model", "estimator": "SVC"}
train_models = ["MLPClassifier"]
PR = PredictPRinKP(datasets_full, datasets_gwas, feature_selection, train_models)
PR.main()

print("finished model training")
# Out:
# ############################# Full datasets #############################
# ----------------Training dataset_1_----------------
# ---- Performing Feature Selection ----
# Method: Select From Model
# Estimator: Suport Vector Classifier
# ---- Completed feature selection ----
# Number of features selected: 623
# Perform Multi-layer Perceptron training.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_476883/2020718708.py in <module>
#       1 feature_selection = {"method": "Select From Model", "estimator": "SVC"}
#       2 PR = PredictPRinKP(datasets_full, datasets_gwas, feature_selection)
# ----> 3 PR.main()
#       4
#       5 print("finished model training")
#
# ~/Insync/arthcrs@gmail.com/Google-Drive/College/TCC/Repositories/predicting-PR-in-KB/notebooks/../src/PredictPRInKP.py in main(self)
#     488         """Save models in the chosen path."""
# ...
